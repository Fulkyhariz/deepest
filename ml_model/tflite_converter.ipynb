# %%
import tensorflow as tf

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model("saved_model/saved_model.pb") # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\fulky\Capstone\ml_model\tflite_converter.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fulky/Capstone/ml_model/tflite_converter.ipynb#ch0000001?line=0'>1</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/fulky/Capstone/ml_model/tflite_converter.ipynb#ch0000001?line=2'>3</a> # Convert the model
#       <a href='vscode-notebook-cell:/c%3A/Users/fulky/Capstone/ml_model/tflite_converter.ipynb#ch0000001?line=3'>4</a> converter = tf.lite.TFLiteConverter.from_saved_model("saved_model/saved_model.pb") # path to the SavedModel directory
#
# File c:\Users\fulky\anaconda3\lib\site-packages\tensorflow\__init__.py:37, in <module>
#      <a href='file:///c%3A/Users/fulky/anaconda3/lib/site-packages/tensorflow/__init__.py?line=33'>34</a> import sys as _sys
# ...
